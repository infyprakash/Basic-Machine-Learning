# %%
print('Hello world')
# Out:
# Hello world

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
age = np.array([20,22,25,30,38,45])
salary = np.array([10000,15000,8000,20000,22000,40000])

# %%
type(age)
# Out:
# numpy.ndarray

# %%
type(salary)
# Out:
# numpy.ndarray

# %%
plt.figure(figsize=(10,10))
plt.plot(age,salary,'ro')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age versus Salary')
plt.show()
